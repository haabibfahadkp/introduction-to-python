# %% [markdown]
# <a href="https://colab.research.google.com/github/haabibfahadkp/introduction-to-python/blob/main/_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
datafile=files.upload()
# Out:
#      <input type="file" id="files-033a4687-3ca3-47cd-b4d5-ac8ab862e320" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-033a4687-3ca3-47cd-b4d5-ac8ab862e320">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df= pd.read_csv("SOCR-HeightWeight.csv")
import matplotlib.pyplot as plt
import plotly.express as px
height=df['Height(Inches)']

weight=df['Weight(Pounds)']
print("Mean Height of the class: ",height.mean())
print("Mean WEeight of the class: ",weight.mean())
print("Median Height of the class: ",height.median())
print("Median Weight of the class: ",weight.median())
print("Mode Height of the class: ",height.mode())
print("Mode Weight of the class: ",weight.mode())
plt.bar(height,weight)
plt.show()
# Out:
# Mean Height of the class:  67.99311359679999
# Mean WEeight of the class:  127.07942116080001
# Median Height of the class:  67.9957
# Median Weight of the class:  127.15775
# Mode Height of the class:  0     65.65796
# 1     67.34629
# 2     67.41672
# 3     67.94061
# 4     67.97769
# 5     67.98509
# 6     68.30287
# 7     68.92380
# 8     68.93456
# 9     68.97830
# 10    70.04724
# dtype: float64
# Mode Weight of the class:  0    124.7975
# dtype: float64

# %%
from google.colab import files
file1=files.upload()
# Out:
#      <input type="file" id="files-3dba36ea-0edd-49db-8a17-546095cd20bd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3dba36ea-0edd-49db-8a17-546095cd20bd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
file2=files.upload()
# Out:
#      <input type="file" id="files-e61b13f9-bf2e-4580-97cf-40cf154cf041" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e61b13f9-bf2e-4580-97cf-40cf154cf041">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import plotly.express as px
df1=pd.read_csv("class1.csv")
df2=pd.read_csv("class2.csv")
fig1=px.scatter(df1,x="Student Number",y="Marks",title="class1")
fig2=px.scatter(df2,x="Student Number",y="Marks",title="class2")
marks1=df1["Marks"]
marks2=df2["Marks"]
average1=marks1.mean()
average2=marks2.mean()
print("class1 average",average1)
print("class2 average",average2)
length=marks1.count()
y0=average1
y1=average2
x0=1
x1=length
fig1.update_layout(shapes=[dict(
type="line",y0=y0,y1=y1,x0=x0,x1=x1
)])
fig1.update_yaxes(rangemode="tozero")
fig2.update_yaxes(rangemode="tozero")
fig1.show()
fig2.show()
print("Standard deviation of Marks of class1 from centeral tendancy",marks1.std())
print("Standard deviation of Marks of class from centeral tendancy",marks2.std())
# Out:
# class1 average 75.0
# class2 average 75.0
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from google.colab import files
file1=files.upload()
# Out:
#      <input type="file" id="files-1f5edc68-0c82-4253-92dd-27899e66c27b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1f5edc68-0c82-4253-92dd-27899e66c27b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("Ice-Cream vs Cold-Drink vs Temperature - Ice Cream Sale vs Temperature data.csv")
import plotly.express as px
fig= px.scatter(df,x="Temperature",y="Ice-cream Sales( ₹ )")
fig.update_yaxes(rangemode="tozero")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
